# %% [markdown]
# ## NEPAL HOUSING DATASET

# %% [markdown]
# ### DATA PRE-PROCESSING
# source-https://www.kaggle.com/datasets/nishanpokh/house-price-dataset-nepal

# %%
#IMPORTING LIBARIES
import pandas as pd
import numpy as np 

import pymongo

# %%
df=pd.read_csv("Raw_housing_dataset.csv")
df.head()
# Out:
#                      TITLE                LOCATION         PRICE LAND AREA  \
# 0           House for Sale        Imadol, Lalitpur   Rs. 2.9 Cr   4.0 aana
# 1           House for Sale     Satdobato, Lalitpur  Rs. 4.75 Cr   3.0 aana
# 2     4 BHK House for Sale        Imadol, Lalitpur  Rs. 1.99 Cr   2.3 aana
# 3  Bungalow House for Sale    Bhaisepati, Lalitpur     Rs. 4 Cr   7.0 aana
# 4           House for Rent  Maharajgunj, Kathmandu  Rs. 12000000  6.0 aana
#
#   BUILDUP AREA ROAD ACCESS      FACING  FLOOR  BEDROOM  BATHROOM BUILT YEAR  \
# 0          NaN     12 Feet        West    3.0      5.0       4.0   2076 B.S
# 1          NaN     10 Feet        West    4.5      5.0       6.0   2076 B.S
# 2          NaN     10 Feet        West    2.5      4.0       4.0   2060 B.S
# 3          NaN     12 Feet  North-West    2.5      4.0       3.0   2059 B.S
# 4          NaN     20 Feet       South    2.0      4.0       4.0   2071 B.S
#
#               PARKING                                          AMENITIES
# 0  1 CaRs.  & 2 Bikes  ['Earthquake Resistant', 'Marbel', 'Parquet', ...
# 1  2 CaRs.  & 2 Bikes  ['Earthquake Resistant', 'Parquet', 'Drinking ...
# 2  1 CaRs.  & 3 Bikes  ['Earthquake Resistant', 'Marbel', 'Parquet', ...
# 3  4 CaRs.  & 4 Bikes  ['Earthquake Resistant', 'Marbel', 'Parquet', ...
# 4  4 CaRs.  & 5 Bikes  ['Earthquake Resistant', 'Parquet', 'Parking',...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3418 entries, 0 to 3417
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TITLE         3418 non-null   object
#  1   LOCATION      3418 non-null   object
#  2   PRICE         3418 non-null   object
#  3   LAND AREA     3329 non-null   object
#  4   BUILDUP AREA  719 non-null    object
#  5   ROAD ACCESS   3409 non-null   object
#  6   FACING        3212 non-null   object
#  7   FLOOR         3323 non-null   float64
#  8   BEDROOM       3136 non-null   float64
#  9   BATHROOM      3072 non-null   float64
#  10  BUILT YEAR    3357 non-null   object
#  11  PARKING       632 non-null    object
#  12  AMENITIES     3418 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 347.3+ KB

# %%
df.isnull().sum()/len(df)*100
# Out:
# TITLE            0.000000
# LOCATION         0.000000
# PRICE            0.000000
# LAND AREA        2.603862
# BUILDUP AREA    78.964307
# ROAD ACCESS      0.263312
# FACING           6.026916
# FLOOR            2.779403
# BEDROOM          8.250439
# BATHROOM        10.122879
# BUILT YEAR       1.784669
# PARKING         81.509655
# AMENITIES        0.000000
# dtype: float64

# %% [markdown]
# From the above observation , we should drop - features (PARKING,BUILDUP AREA)

# %%
feature_to_drop=['PARKING',"BUILDUP AREA","TITLE","AMENITIES"]

# %% [markdown]
# ##

# %% [markdown]
# ### DROPING ALL THE RENTED and LAND LISTING

# %%
rent = df['TITLE'].str.contains("rent", case=False, na=False)
land= df['PRICE'].str.contains("Lac/", case=False, na=False)
df = df[~rent]
df=df[~land]
# Out:
# C:\Users\tsaja\AppData\Local\Temp\ipykernel_8392\3340594647.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df=df[~land]

# %% [markdown]
# ### ARRANGING THE PRICE COLUMN

# %%
df['PRICE'].unique()
# Out:
# array(['Rs. 2.9 Cr ', 'Rs. 4.75 Cr ', 'Rs. 1.99 Cr ', 'Rs. 4 Cr ',
#        'Rs. 3.3 Cr ', 'Rs. 4.5 Cr ', 'Rs. 3 Cr', 'Rs. 4.99 Cr ',
#        'Rs. 2.45 Cr ', 'Rs. 2.5 Cr ', 'Rs. 4.25 Cr ', 'Rs. 6.5 Cr ',
#        'Rs. 3.6 Cr ', 'Rs. 5.8 Cr ', 'Rs. 4.8 Cr ', 'Rs. 6.65 Cr ',
#        'Rs. 13.3 Cr ', 'Rs. 8.5 Cr ', 'Rs. 5.5 Cr ', 'Rs. 2.95 Cr ',
#        'Rs. 6.35 Cr ', 'Rs. 10.5 Cr ', 'Rs. 6.4 Cr ', 'Rs. 3.5 Cr ',
#        'Rs. 2.2 Cr ', 'Rs. 3.75 Cr ', 'Rs. 8 Cr ', 'Rs. 7.75 Cr ',
#        'Rs. 16 Cr ', 'Rs. 3.19 Cr ', 'Rs. 12 Cr ', 'Rs. 6.25 Cr ',
#        'Rs. 2.8 Cr ', 'Rs. 5.99 Cr ', 'Rs. 6 Cr ', 'Rs. 2.7 Cr ',
#        'Rs. 2.75 Cr ', 'Rs. 11 Cr ', 'Rs. 3.25 Cr ', 'Rs. 3.1 Cr ',
#        'Rs. 4 Cr', 'Rs. 3.15 Cr ', 'Rs. 4.65 Cr ', 'Rs. 5.95 Cr ',
#        'Rs. 3.9 Cr ', 'Rs. 3.2 Cr ', 'Rs. 5.15 Cr ', 'Rs. 2.3 Cr ',
#        'Rs. 1.7 Cr ', 'Rs. 2.4 Cr ', 'Rs. 2.25 Cr ', 'Rs. 1.8 Cr ',
#        'Rs. 1.65 Cr ', 'Rs. 5.1 Cr ', 'Rs. 1.27 Cr ', 'Rs. 6.1 Cr ',
#        'Rs. 3.69 Cr ', 'Rs. 1.55 Cr ', 'Rs. 1.33 Cr ', 'Price on call',
#        'Rs. 1.6 Cr ', 'Rs. 3.99 Cr ', 'Rs. 5.25 Cr ', 'Rs. 2.35 Cr ',
#        'Rs. 3.3 Cr', 'Rs. 8.5 Cr', 'Rs. 6.03 Cr', 'Rs. 7.5 Cr ',
#        'Rs. 2.85 Cr ', 'Rs. 2.55 Cr ', 'Rs. 2.65 Cr ', 'Rs. 3.4 Cr ',
#        'Rs. 3.55 Cr ', 'Rs. 5.9 Cr ', 'Rs. 4.25 Cr', 'Rs. 3.45 Cr ',
#        'Rs. 4.2 Cr ', 'Rs. 4.6 Cr ', 'Rs. 3.85 Cr ', 'Rs. 2.6 Cr ',
#        'Rs. 5 Cr ', 'Rs. 3.7 Cr ', 'Rs. 7.25 Cr ', 'Rs. 3.65 Cr ',
#        'Rs. 4.65 Cr', 'Rs. 1.5 Cr ', 'Rs. 1.9 Cr ', 'Rs. 4.35 Cr ',
#        'Rs. 1.95 Cr ', 'Rs. 2.60 Cr ', 'Rs. 4.7 Cr ', 'Rs. 9 Cr ',
#        'Rs. 7 Cr ', 'Rs. 18 Cr ', 'Rs. 2.6 Cr', 'Rs. 3 Cr ',
#        'Rs. 1.75 Cr ', 'Rs. 4.3 Cr ', 'Rs. 15 Cr ', 'Rs. 12.5 Cr ',
#        'Rs. 3.35 Cr ', 'Rs. 5.75 Cr ', 'Rs. 7.6 Cr ', 'Rs. 7.35 Cr ',
#        'Rs. 1.6 Cr', 'Rs. 90 Lac ', 'Rs. 5.55 Cr ', 'Rs. 14 Cr ',
#        'Rs. 3.38 Cr ', 'Rs. 7.3 Cr ', 'Rs. 65 Lac ', 'Rs. 4.95 Cr ',
#        'Rs. 2.15 Cr ', 'Rs. 3.8 Cr ', 'Rs. 27500000  ', 'Rs. 5.65 Cr ',
#        'Rs. 2 Cr ', 'Rs. 6.75 Cr ', 'Rs. 1.68 Cr ', 'Rs. 1.73 Cr ',
#        'Rs. 7.7 Cr ', 'Rs. 2.99 Cr ', 'Rs. 13.5 Cr ', 'Rs. 2.1 Cr ',
#        'Rs. 1.3 Cr ', 'Rs. 1.85 Cr ', 'Rs. 10.4 Cr', 'Rs. 2.95 Cr',
#        'Rs. 6.8 Cr ', 'Rs. 5.49 Cr ', 'Rs. 3.70 Cr', 'Rs. 1.2 Cr ',
#        'Rs. 10 Cr ', 'Rs. 3.05 Cr ', 'Rs. 15 Lac ', 'Price on call ',
#        'Rs. 1.78 Cr ', 'Rs. 1 Cr ', 'Rs. 8.3 Cr ', 'Rs. 11.5 Cr ',
#        'Rs. 3.87 Cr ', 'Rs. 2.24 Cr ', 'Rs. 4.9 Cr ', 'Rs. 1.96 Cr ',
#        'Rs. 2.84 Cr ', 'Rs. 1.62 Cr ', 'Rs. 4.1 Cr ', 'Rs. 4.45 Cr ',
#        'Rs. 60 Lac ', 'Rs. 5.7 Cr ', 'Rs. 4.17 Cr ', 'Rs. 3.9 Cr',
#        'Rs. 1.4 Cr ', 'Rs. 3.88 Cr ', 'Rs. 3.98 Cr ', 'Rs. 5.86 Cr ',
#        'Rs. 5.2 Cr ', 'Rs. 2.88 Cr ', 'Rs. 7.8 Cr ', 'Rs. 6.6 Cr ',
#        'Rs. 2.19 Cr ', 'Rs. 1.88 Cr ', 'Rs. 7.1 Cr ', 'Rs. 3.95 Cr ',
#        'Rs. 1.35 Cr ', 'Rs. 1.45 Cr ', 'Rs. 13.8 Cr ', 'Rs. 7.4 Cr ',
#        'Rs. 4.15 Cr ', 'Rs. 2.04 Cr ', 'Rs. 8.2 Cr ', 'Rs. 4.19 Cr ',
#        'Rs. 5.6 Cr ', 'Rs. 6.15 Cr ', 'Rs. 2.05 Cr ', 'Rs. 4.98 Cr ',
#        'Rs. 2.98 Cr ', 'Rs. 1.31 Cr ', 'Rs. 6.2 Cr ', 'Rs. 7.65 Cr ',
#        'Rs. 5.4 Cr ', 'Rs. 5.35 Cr ', 'Rs. 17 Cr ', 'Rs. 19 Cr ',
#        'Rs. 10.2 Cr ', 'Rs. 9.5 Cr ', 'Rs. 4.05 Cr ', 'Rs. 13 Cr ',
#        'Rs. 8.75 Cr ', 'Rs. 85 Lac ', 'Rs. 8.8 Cr ', 'Rs. 21 Cr ',
#        'Rs. 40 Cr ', 'Rs. 2.68 Cr ', 'Rs. 3.55 Cr', 'Rs. 9.2 Cr ',
#        'Rs. 2.85 Cr', 'Rs. 7.2 Cr ', 'Rs. 1.85 Cr', 'Rs. 1.25 Cr ',
#        'Rs. 2.49 Cr ', 'Rs. 9.6 Cr ', 'Rs. 5.3 Cr ', 'Rs. 6.74 Cr ',
#        'Rs. 3.7 Cr', 'Rs. 1.98 Cr ', 'Rs. 17.5 Cr ', 'Rs. 4.4 Cr ',
#        'Rs. 4.55 Cr ', 'Rs. 6.9 Cr ', 'Rs. 7.15 Cr ', 'Rs. 9.25 Cr ',
#        'Rs. 1.1 Cr ', 'Rs. 7.95 Cr ', 'Rs. 3.78 Cr ', 'Rs. 4.85 Cr ',
#        'Rs. 1.89 Cr ', 'Rs. 4.48 Cr ', 'Rs. 14.5 Cr ', 'Rs. 3.22 Cr ',
#        'Rs. 16.5 Cr ', 'Rs. 6.55 Cr ', 'Rs. 2.23 Cr ', 'Rs. 1.43 Cr ',
#        'Rs. 1.38 Cr ', 'Rs. 68 Lac ', 'Rs. 5.85 Cr ', 'Rs. 22 Lac ',
#        'Rs. 2.22 Cr ', 'Rs. 95 Lac ', 'Rs. 1.05 Cr ', 'Rs. 4.5 Cr',
#        'Rs. 25 Cr ', 'Rs. 2.67 Cr ', 'Rs. 1.1 /aana', 'Rs. 20 Cr ',
#        'Rs. 80 Lac ', 'Rs. 1.12 Cr ', 'Rs. 3.90 Cr ', 'Rs. 1.18 Cr ',
#        'Rs. 2.97 Cr ', 'Rs. 2.87 Cr ', 'Rs. 1.58 Cr ', 'Rs. 38 Lac ',
#        'Rs. 1.15 Cr ', 'Rs. 2.11 Cr ', 'Rs. 2.72 Cr ', 'Rs. 75 Lac ',
#        'Rs. 6.7 Cr ', 'Rs. 3.5 Cr', 'Rs. 98 Lac ', 'Rs. 2.18 Cr ',
#        'Rs. 2.5 Cr', 'Rs. 78 Lac ', 'Rs. 2.07 Cr ', 'Rs. 2.68 Lac ',
#        'Rs. 98.5 Lac ', 'Rs. 1.82 Cr ', 'Rs. 1.28 Cr ', 'Rs. 9800000 ',
#        'Rs. 26 Cr ', 'Rs. 9.75 Cr ', 'Rs. 2.38 Cr ', 'Rs. 3.28 Cr ',
#        'Rs. 82 Lac ', 'Rs. 2.03 Cr ', '25000000', 'Rs.  22000000',
#        'Rs.  2.25 Cr', 'Rs.  2,50,00,000', 'Rs.  3.50 Cr',
#        'Rs.  16,00,00,000', 'Rs.  30000000', 'Rs.  2.60 Cr',
#        'Rs.  3.8 Cr', 'Rs.  22,000,000', 'Rs.  20000000',
#        'Rs.  27,500,000', 'Rs.  2.2 Cr', 'Rs. 7,35,00,000',
#        'Rs. 1,65,00,000', 'Rs.  18500000', 'Rs.  11500000',
#        'Rs.  17000000', 'Rs. 33,000,000', 'Rs.  31000000',
#        'Rs.  23500000', 'Rs. 12,00,00,000', 'Rs. 4.50 Cr', 'Rs. 31500000',
#        'Rs.  60000000', 'Rs. 25500000 ', 'Rs. 61500000 ', 'Rs. 50000000',
#        'Rs. 38,500,000', 'Rs. 36000000', 'Rs. 31,000,000 ',
#        'Rs. 28,500,000', 'Rs. 35,500,000', 'Rs. 55,000,000',
#        'Rs. 42,500,000', 'Rs. 270,00,000 ', 'Rs. 22,500,000',
#        'Rs. 38,000,000', 'Rs. 4.2 Cr', 'Rs. 24500000', 'Rs. 68,000,000',
#        'Rs. 45000000', 'Rs. 80,000,000', 'Rs. 29,900,000', 'Rs. 37500000',
#        'Rs. 325000000', 'Rs. 28500000', 'Rs. 60000000', 'Rs. 41,500,000',
#        'Rs. 42000000', 'Rs. 26500000', 'Rs. 37,500,000', 'Rs. 22500000',
#        'Rs. 26,000,000', 'Rs. 29500000', 'Rs. 33,500,000', 'Rs. 30000000',
#        'Rs. 38500000', 'Rs. 27500000', 'Rs. 34500000', 'Rs. 49000000',
#        'Rs. 27000000', 'Rs. 25000000', 'Rs. 390,00,000', 'Rs. 15500000',
#        'Rs. 33000000', 'Rs. 14,500,000', 'Rs. 127,500,000',
#        'Rs. 21,500,000', 'Rs. 65000000', 'Rs. 41000000 ', 'Rs. 47000000',
#        'Rs. 25,500,000', 'Rs. 32,000,000', 'Rs. 23500000', 'Rs. 39800000',
#        'Rs. 34000000', 'Rs. 32000000', 'Rs. 39,500,000', 'Rs. 26000000',
#        'Rs. 19500000', 'Rs. 18500000', 'Rs. 46500000', 'Rs. 29000000',
#        'Rs. 35000000', 'Rs. 2,25,00,000', 'Rs. 3.20 Cr', 'Rs. 55000000',
#        'Rs. 40000000', 'Rs. 75000000', 'Rs. 6,0000,000', 'Rs. 31000000',
#        'Rs. 22,000,000', 'Rs. 20500000', 'Rs. 1.8 Cr', 'Rs. 24000000',
#        'Rs. 39000000', 'Rs. 47,000,000', 'Rs. 5 Cr', 'Rs. 125000000',
#        'Rs. 33500000', 'Rs. 28000000', 'Rs. 32500000', 'Rs. 30500000',
#        'Rs. 43000000', 'Rs. 30,500,000', 'Rs. 7.75 Cr', 'Rs. 23,500,000',
#        'Rs. 46,500,000', 'Rs. 40,000,000', 'Rs. 2,90,00,000',
#        'Rs. 2,75,00,000', 'Rs. 20,000,000', 'Rs. 62000000',
#        'Rs. 30,000,000', 'Rs. 47,500,000', 'Rs. 3,00,00,000',
#        'Rs. 18,500,000', 'Rs. 25,000,000', 'Rs. 27,000,000',
#        'Rs. 37,000,000', 'Rs. 35,000,000', 'Rs. 16000000',
#        'Rs. 27,500,000', 'Rs. 3,30,00,000', 'Rs. 4.75 Cr',
#        'Rs. 23,000,000', 'Rs. 7 Cr', 'Rs. 3,65,00,000', 'Rs. 31,500,000',
#        'Rs. 7,00,00,000', 'Rs. 2,70,00,000', 'Rs. 23000000',
#        'Rs. 2,30,00,000', 'Rs. 24,000,000', 'Rs. 105,000,000',
#        'Rs. 45,000,000', 'Rs. 120,000,000', 'Rs. 100000000',
#        'Rs. 90,000,000', 'Rs. 185,000,000', 'Rs. 36,000,000',
#        'Rs. 3,40,00,000', 'Rs. 1,80,00,000', 'Rs. 1,40,00,000',
#        'Rs. 34,000,000', 'Rs. 5,25,00,000', 'Rs. 21,000,000',
#        'Rs. 48000000'], dtype=object)

# %%
df.sample(5)
# Out:
#                                                   TITLE  \
# 2379               New house on sale in Kapan, Paiyutar
# 3063                       House on sale in Chandragiri
# 2297                  Brand new house for sale in Kapan
# 1310  Residential house for sale at Ichangunarayan, ...
# 1465        House for sale in Mangal Colony, Bhaisepati
#
#                         LOCATION         PRICE LAND AREA BUILDUP AREA  \
# 2379        Paiyuntar, Kathmandu  Rs. 1.35 Cr   3.2 aana          NaN
# 3063          Thankot, Kathmandu   Rs. 85 Lac   4.0 aana          NaN
# 2297            Kapan, Kathmandu   Rs. 2.4 Cr   3.3 aana          NaN
# 1310  Ichangu Narayan, Kathmandu  Rs. 2.15 Cr   2.2 aana          NaN
# 1465        Bhaisepati, Lalitpur     Rs. 4 Cr   5.0 aana          NaN
#
#      ROAD ACCESS FACING  FLOOR  BEDROOM  BATHROOM BUILT YEAR PARKING  \
# 2379     13 Feet   East    1.0      2.0       1.0   2070 B.S     NaN
# 3063  12-16 Feet    NaN    NaN      NaN       NaN   2076 B.S     NaN
# 2297     12 Feet   West    2.5      6.0       5.0   2072 B.S     NaN
# 1310      9 Feet   West    2.5      4.0       4.0   2076 B.S     NaN
# 1465     20 Feet   West    2.5      5.0       4.0   2075 B.S     NaN
#
#                                               AMENITIES
# 2379  ['Bathroom', 'Drainage', 'Earthquake Resistant...
# 3063  ['Drainage', 'Water Well', 'Power Backup', 'Pa...
# 2297  ['Marbel', 'Drainage', 'Bathroom', 'Drinking W...
# 1310  ['Power Backup', 'Drainage', 'Drinking Water',...
# 1465  ['Drainage', 'Bathroom', 'Drinking Water', 'Ma...

# %% [markdown]
# ### PRICE

# %%
def pricing(price):
    price=price.lower()
    try:
        if "cr" in price:
            split_cr=price.split()
            price=float(split_cr[1])*10000000
            price=int(price)
    except :pass
    try:
        if "lac" in price:
            split_lac=price.split()
            price=float(split_lac[1])*1000000
            price=int(price)
    except :pass
    try:
        if "," in price:
            price=price.split()[1]
            price=price.split(",")
            price=int("".join(price))
    except:pass
    try:
        if "price on call"  in price:
            price=np.nan
    except: pass
    try:
        if "/aana"  in price:
            price=np.nan
    except: pass
    try:
        price=int(price.split()[1])
    except:pass
    
    return price

df['PRICE']=df['PRICE'].apply(pricing)

# %% [markdown]
# ### LAND

# %%
df['LAND AREA'].unique()
# Out:
# array(['4.0 aana', '3.0 aana', '2.3 aana', '7.0 aana', '3.2 aana',
#        '4.3 aana', '2.2 aana', '5.0 aana', '5.2 aana', '6.2 aana',
#        '4.2 aana', '4.1 aana', '9.6 aana', '3.1 aana', '11.0 aana',
#        '6.0 aana', '3.3 aana', '9.0 aana', '12 aana', '6.4 aana',
#        '12.0 aana', '3.5 aana', '6 aana', '7.1 aana', '6.3 aana',
#        '15.0 aana', '9.3 aana', '9.1 aana', '0.14 kattha', '6.1 aana',
#        '2.9 aana', '7.2 aana', '8.0 aana', '10.2 aana', '127 sq. mtr',
#        '22.0 aana', '7.3 aana', '5.1 aana', '10.0 aana', '1.0 aana',
#        '5.3 aana', '24.0 aana', '2.5 aana', '0.12 kattha', '0.5 kattha',
#        '14.0 aana', '1.2 aana', '8.2 aana', '1.1 aana', '3.8 aana',
#        '13.0 aana', '16.0 aana', '1.9 kattha', '0.11 kattha', '9.2 aana',
#        nan, '3.4 aana', '2.8 aana', '17.0 aana', '1.7 kattha',
#        '0.10 kattha', '1.3 kattha', '3 aana', '11.2 aana', '10.3 aana',
#        '0.15 kattha', '3.2 kattha', '4 aana', '1.5 kattha', '5.0 kattha',
#        '6.7 aana', '4.5 aana', '0.3 aana', '5 aana ', '2.0 aana',
#        '8.3 aana', '936 sq. ft', '51.0 aana', '9.5 aana', '2.3 kattha',
#        '0.7 kattha', '49.0 aana', '7.5 aana', '14.3 aana', '5.5 aana',
#        '18.0 aana', '8.1 aana', '1.3 aana', '32.0 aana', '4.0  aana',
#        '10.0 kattha', '2.7 aana', '3.0 kattha', '0 sq. ft', '12.1 aana',
#        '1200 sq. ft', '0.8 kattha', '5 aana', '1100 sq. ft', '21.3 aana',
#        '2.1 aana', '4.5 sq. ft', '9.2 kattha', '5.2 kattha', '27.0 aana',
#        '6.5 aana', '21.0 aana', '7.7 aana', '13.3 aana', '15.3 aana',
#        '7 aana', '3.3 kattha', '4.4 aana', '6.2 kattha', '15.2 aana',
#        '0.13 kattha', '2233.81 sq. ft', '2.6 aana', '1275 sq. ft',
#        '0.925 kattha', '2 aana', '594 sq. ft', '3 aana ', '13.2 aana',
#        '10.1 aana', '38.0 aana', '17.2 aana', '2.4 aana', '12.2 aana',
#        '1250 sq. ft', '8.6 aana', '11.1 aana', '26.0 aana', '6.0 kattha',
#        '8 aana', '3.75 aana', '75.0 aana', '7.8 aana', '23.0 aana',
#        '3.7 aana', '4.7 aana', '9.25', '14.5 aana', '2.5', '16 aana',
#        '14 aana', '4 aana ', '9 aana', '20 aana', '4.2', '4.6 aana',
#        '10 aana', '11 aana', '5.4 aana', '21 aana', '4.5 aana ',
#        '3.6 aana', '4.7 aana '], dtype=object)

# %%
anna_to_sqf=342.25
kattha_to_sqf=3645.013

def land(area):
    try:    
        area=area.lower()
        try:
            if "aana" in area:
                area=area.split()[0]
                area=float(area)*anna_to_sqf
        except:pass
        try:
            if "kattha" in area:
                area=area.split()[0]
                area=float(area)*kattha_to_sqf
        except: pass
        try:
            if "sq" in area:
                area=float(area.split()[0])
        except : pass
    except:pass
    return area


df['LAND AREA']=round(df['LAND AREA'].apply(land),2)

# %% [markdown]
# ### ROAD ACESS

# %%
df["ROAD ACCESS"].unique()
# Out:
# array(['12 Feet', '10 Feet', '13 Feet', '14 Feet', '16 Feet', '20 Feet',
#        '26 Feet', '25 Feet', '18 Feet', '15 Feet', '24 Feet', '27 Feet',
#        '30 Feet', '9 Meter', '23 Feet', '8 Feet', '11 Feet', '22 Feet',
#        '20 Meter', '35 Feet', '6 Feet', '4 Feet', '10 Meter', '17 Feet',
#        nan, '13 Meter', '13-20 Feet', '10-12 Feet', '12-18 Feet',
#        '10-15 Feet', '12-16 Feet', '32 Feet', '12/20 Feet', '9 Feet',
#        '12-14 Feet', '15-26 Feet', '5 Feet', '10-20 Feet', '15-20 Feet',
#        '14-20 Feet', '12-13 Feet', '8-10 Feet', '12/13 Feet', '20  Feet',
#        '9-12 Feet', '13  Feet', '10/13 Feet', '10-24 Feet', '16-22 Feet',
#        '20-26 Feet', '13-16 Feet', '12-15 Feet', '8-12 Feet',
#        '15-24 Feet', '13-24 Feet', '10-26 Feet', '13-15 Feet', '36 Feet',
#        '12-20 Feet', '10-14 Feet', '12-26 Feet', '13-18 Feet', '15 Meter',
#        '21 Feet', '0 Feet', '16-20 Feet', '10-16 Feet', '40 Feet',
#        '10-18 Feet', '11-14 Feet', '10/16 Feet', '26-30 Feet',
#        '10-13 Feet', '30-32 Feet', '8-14 Feet', '13-14 Feet', '5-8 Feet',
#        '14  Feet', '13/20 Feet', '14-22 Feet', '28 Feet', '82 Feet',
#        '4-8 Feet', '16/20 Feet', '16/10 Feet', '14-18 Feet', '13/16 Feet',
#        '10/26 Feet', '13/18 Feet', '10/15 Feet', '20/6 Feet',
#        '14/16 Feet', '13/22 Feet', '65 Feet', '12/8 Feet', '10  Feet',
#        '12  Feet', '12/16 Feet', '20/14 Feet', '18-20 Feet', '18-26 Feet',
#        '14/22 Feet', '15-16 Feet', '18-22 Feet', '8-13 Feet',
#        '14/26 Feet', '12/14 Feet', '13-33 Feet', '12 & 22 Feet',
#        '10/20 Feet', '12Feet', '13 feet', "8 Feet's", '20', '7 FT', '13',
#        '22 meteRs.', '10', '12', '20 feet', '16 feet'], dtype=object)

# %%
meter_to_ft=29.5276
def road(road_size):
    try:
        road_size=road_size.lower()
        try:
            road_size=road_size.split()
            if len(road_size)==2:
                if '/' in road_size[0]:
                    road_size=road_size[0].split("/")[0]
                    road_size=int(road_size)
                elif "-" in road_size[0]:
                    road_size=road_size[0].split("-")[0]
                    road_size=int(road_size)
                elif "meter" in road_size:
                    road_size=float(road_size[0])*meter_to_ft
                    road_size=int(round(road_size))
                else :
                    road_size=int(road_size[0])
            else:
                return int(road_size[0])
        except:pass
    except:pass
    return road_size

df['ROAD ACCESS']=df['ROAD ACCESS'].apply(road)

# %% [markdown]
# ### BUILD UP YEAR

# %%
def build_year(year):
    try:
        year=year.split()[0]
        year=2081-int(year)
    except:
        year=None
    return year
df["BUILT YEAR"]=df["BUILT YEAR"].apply(build_year)

# %%
'''df['AMENITIES'].str.split(',')'''
# Out:
# "df['AMENITIES'].str.split(',')"

# %%
"""amenities_list=[]

for animities in df['AMENITIES']:
    amenities_list.append(animities)
"""
# Out:
# "amenities_list=[]\n\nfor animities in df['AMENITIES']:\n    amenities_list.append(animities)\n"

# %%
"""import ast
list_of_lists = [ast.literal_eval(item) for item in amenities_list]


unique_items = sorted(set(item for sublist in list_of_lists for item in sublist))

for item in unique_items:
    df[item] = df["AMENITIES"].apply(lambda x: 1 if item in x else 0)"""
# Out:
# 'import ast\nlist_of_lists = [ast.literal_eval(item) for item in amenities_list]\n\n\nunique_items = sorted(set(item for sublist in list_of_lists for item in sublist))\n\nfor item in unique_items:\n    df[item] = df["AMENITIES"].apply(lambda x: 1 if item in x else 0)'

# %%
df.head()
# Out:
#                      TITLE              LOCATION     PRICE LAND AREA  \
# 0           House for Sale      Imadol, Lalitpur  29000000    1369.0
# 1           House for Sale   Satdobato, Lalitpur  47500000   1026.75
# 2     4 BHK House for Sale      Imadol, Lalitpur  19900000   787.175
# 3  Bungalow House for Sale  Bhaisepati, Lalitpur  40000000   2395.75
# 6     3 BHK House for Sale  Bhaisepati, Lalitpur  33000000    1095.2
#
#   BUILDUP AREA ROAD ACCESS      FACING  FLOOR  BEDROOM  BATHROOM  BUILT YEAR  \
# 0          NaN          12        West    3.0      5.0       4.0         5.0
# 1          NaN          10        West    4.5      5.0       6.0         5.0
# 2          NaN          10        West    2.5      4.0       4.0        21.0
# 3          NaN          12  North-West    2.5      4.0       3.0        22.0
# 6          NaN          13  North-West    2.5      4.0       3.0         7.0
#
#               PARKING                                          AMENITIES
# 0  1 CaRs.  & 2 Bikes  ['Earthquake Resistant', 'Marbel', 'Parquet', ...
# 1  2 CaRs.  & 2 Bikes  ['Earthquake Resistant', 'Parquet', 'Drinking ...
# 2  1 CaRs.  & 3 Bikes  ['Earthquake Resistant', 'Marbel', 'Parquet', ...
# 3  4 CaRs.  & 4 Bikes  ['Earthquake Resistant', 'Marbel', 'Parquet', ...
# 6  4 CaRs.  & 5 Bikes  ['Earthquake Resistant', 'Marbel', 'Parquet', ...

# %%
df['FACING'].value_counts()
# Out:
# FACING
# East            588
# South           532
# West            407
# North           402
# South-East      216
# North-East      155
# South-West      132
# North-West       82
# EAST             29
# SOUTH            25
# NORTH            22
# WEST             17
# North East       13
# EAST-NORTH       13
# South East       12
# South West       10
# SOUTH-WEST        8
# EAST-SOUTH        6
# East-South        5
# NORTH-WEST        4
# NORTH/EAST        3
# North West        3
# SOUTH-EAST        3
# South-EAST        3
# south             2
# west              2
# East/South        1
# WEST /NORTH       1
# south west        1
# WEST / NORTH      1
# EAST/WEST         1
# East-North        1
# West-South        1
# South-east        1
# WEST-NORTH        1
# WEST-SOUTH        1
# Name: count, dtype: int64

# %%
def facing_structure(facing):
    try:
        facing=facing.lower()
        try:
             if '/' in facing:
                 facing=facing.split('/')
                 facing.sort()
                 facing="-".join(facing)
        except: pass

        try:
            if '-' in facing:
                facing=facing.split('-')
                facing.sort()
                facing='-'.join(facing)
        except: pass
        try:
            facing=facing.split()
            if len(facing)==2:
                facing="-".join(facing)
            else:pass
                
        except:pass
    except :
        None

    return facing

df['FACING']=df['FACING'].apply(facing_structure)
df['FACING']=df['FACING'].explode()

# %% [markdown]
# ### DROPING COLUMNS

# %%
df=df.drop(columns=feature_to_drop,axis=1)

# %%
df=df.rename(columns={"BUILT YEAR":"PROPERTY AGE"})
df.head()
# Out:
#                LOCATION     PRICE LAND AREA ROAD ACCESS      FACING  FLOOR  \
# 0      Imadol, Lalitpur  29000000    1369.0          12        west    3.0
# 1   Satdobato, Lalitpur  47500000   1026.75          10        west    4.5
# 2      Imadol, Lalitpur  19900000   787.175          10        west    2.5
# 3  Bhaisepati, Lalitpur  40000000   2395.75          12  north-west    2.5
# 6  Bhaisepati, Lalitpur  33000000    1095.2          13  north-west    2.5
#
#    BEDROOM  BATHROOM  PROPERTY AGE
# 0      5.0       4.0           5.0
# 1      5.0       6.0           5.0
# 2      4.0       4.0          21.0
# 3      4.0       3.0          22.0
# 6      4.0       3.0           7.0

# %% [markdown]
# ### PUSING DATA INTO MOGODB

# %%
dict_data=df.to_dict(orient="records")

# %% [markdown]
# ### SETTING THE IMPORTANT CONSTATNS

# %%
DB_NAME='ktmhousingproject'
COLLECTION_NAME='housing_data'
CONNECTION_URL='mongodb+srv://tsajan001:hi321@cluster0.gyg64.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %% [markdown]
# ### PUSHING DATA INTO DATABASE

# %%
client=pymongo.MongoClient(CONNECTION_URL)
data_base=client[DB_NAME]
collection=data_base[COLLECTION_NAME]
rec = collection.insert_many(dict_data)

# %% [markdown]
# ### PULLING DATA FROM MONGODB

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('6799e304a695e4e0efb5b13a'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 29000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 12, 'FACING': 'west', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 1: {'_id': ObjectId('6799e304a695e4e0efb5b13b'), 'LOCATION': 'Satdobato, Lalitpur', 'PRICE': 47500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 10, 'FACING': 'west', 'FLOOR': 4.5, 'BEDROOM': 5.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 5.0}
# 2: {'_id': ObjectId('6799e304a695e4e0efb5b13c'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 19900000, 'LAND AREA': 787.175, 'ROAD ACCESS': 10, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 21.0}
# 3: {'_id': ObjectId('6799e304a695e4e0efb5b13d'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 40000000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 12, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 22.0}
# 4: {'_id': ObjectId('6799e304a695e4e0efb5b13e'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 33000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 5: {'_id': ObjectId('6799e304a695e4e0efb5b13f'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 40000000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 14, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 16.0}
# 6: {'_id': ObjectId('6799e304a695e4e0efb5b140'), 'LOCATION': 'Gyaneshwor, Kathmandu', 'PRICE': 45000000, 'LAND AREA': 752.95, 'ROAD ACCESS': 10, 'FACING': 'west', 'FLOOR': 5.5, 'BEDROOM': 13.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 15.0}
# 7: {'_id': ObjectId('6799e304a695e4e0efb5b141'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 30000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 12, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 6.0}
# 8: {'_id': ObjectId('6799e304a695e4e0efb5b142'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 49900000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 2.0}
# 9: {'_id': ObjectId('6799e304a695e4e0efb5b143'), 'LOCATION': 'Kharibot, Kathmandu', 'PRICE': 24500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 11.0}
# 10: {'_id': ObjectId('6799e304a695e4e0efb5b144'), 'LOCATION': 'Bafal, Kathmandu', 'PRICE': 25000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east-south', 'FLOOR': 4.0, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 11: {'_id': ObjectId('6799e304a695e4e0efb5b145'), 'LOCATION': 'Khumaltar, Lalitpur', 'PRICE': 42500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 20, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 12: {'_id': ObjectId('6799e304a695e4e0efb5b146'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 65000000, 'LAND AREA': 2121.9500000000003, 'ROAD ACCESS': 12, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 13: {'_id': ObjectId('6799e304a695e4e0efb5b147'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 36000000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 14: {'_id': ObjectId('6799e304a695e4e0efb5b148'), 'LOCATION': 'Khumaltar, Lalitpur', 'PRICE': 58000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 14, 'FACING': 'north-west', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 3.0}
# 15: {'_id': ObjectId('6799e304a695e4e0efb5b149'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 25000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 12, 'FACING': 'east-south', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 7.0, 'PROPERTY AGE': 3.0}
# 16: {'_id': ObjectId('6799e304a695e4e0efb5b14a'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 48000000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 16, 'FACING': 'east-south', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 17: {'_id': ObjectId('6799e304a695e4e0efb5b14b'), 'LOCATION': 'Tahachal, Kathmandu', 'PRICE': 66500000, 'LAND AREA': 1403.225, 'ROAD ACCESS': 20, 'FACING': 'north', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 18: {'_id': ObjectId('6799e304a695e4e0efb5b14c'), 'LOCATION': 'Dhapasi, Kathmandu', 'PRICE': 133000000, 'LAND AREA': 3285.6, 'ROAD ACCESS': 14, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 19: {'_id': ObjectId('6799e304a695e4e0efb5b14d'), 'LOCATION': 'Thecho, Lalitpur', 'PRICE': 85000000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 12, 'FACING': 'east', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 7.0, 'PROPERTY AGE': 3.0}
# 20: {'_id': ObjectId('6799e304a695e4e0efb5b14e'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 55000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 12, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 21: {'_id': ObjectId('6799e304a695e4e0efb5b14f'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 47500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 20, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 6.0}
# 22: {'_id': ObjectId('6799e304a695e4e0efb5b150'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 29500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 6.0}
# 23: {'_id': ObjectId('6799e304a695e4e0efb5b151'), 'LOCATION': 'Sanepa, Lalitpur', 'PRICE': 63500000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 10, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 24: {'_id': ObjectId('6799e304a695e4e0efb5b152'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 85000000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 6.0}
# 25: {'_id': ObjectId('6799e304a695e4e0efb5b153'), 'LOCATION': 'Maharajgunj, Kathmandu', 'PRICE': 105000000, 'LAND AREA': 3764.75, 'ROAD ACCESS': 12, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 26: {'_id': ObjectId('6799e304a695e4e0efb5b154'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 64000000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 26, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 6.0}
# 27: {'_id': ObjectId('6799e304a695e4e0efb5b155'), 'LOCATION': 'Sunakothi, Lalitpur', 'PRICE': 35000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 20, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 1.0}
# 28: {'_id': ObjectId('6799e304a695e4e0efb5b156'), 'LOCATION': 'Kapan, Kathmandu', 'PRICE': 22000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 29: {'_id': ObjectId('6799e304a695e4e0efb5b157'), 'LOCATION': 'Dhobighat, Lalitpur', 'PRICE': 37500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 30: {'_id': ObjectId('6799e304a695e4e0efb5b158'), 'LOCATION': 'Hattiban, Lalitpur', 'PRICE': 80000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 20, 'FACING': 'south', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 31: {'_id': ObjectId('6799e304a695e4e0efb5b159'), 'LOCATION': 'Satdobato, Lalitpur', 'PRICE': 55000000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'east-south', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 7.0, 'PROPERTY AGE': 4.0}
# 32: {'_id': ObjectId('6799e304a695e4e0efb5b15a'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 55000000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 6.0}
# 33: {'_id': ObjectId('6799e304a695e4e0efb5b15b'), 'LOCATION': 'Sanepa, Lalitpur', 'PRICE': 77500000, 'LAND AREA': 3080.25, 'ROAD ACCESS': 20, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 34: {'_id': ObjectId('6799e304a695e4e0efb5b15c'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 160000000, 'LAND AREA': 4107.0, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 7.0, 'PROPERTY AGE': 7.0}
# 35: {'_id': ObjectId('6799e304a695e4e0efb5b15d'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 31900000, 'LAND AREA': 1403.225, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 36: {'_id': ObjectId('6799e304a695e4e0efb5b15e'), 'LOCATION': 'Sitapaila, Kathmandu', 'PRICE': 25000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 37: {'_id': ObjectId('6799e304a695e4e0efb5b15f'), 'LOCATION': 'Pokhara, Kaski', 'PRICE': 120000000, 'LAND AREA': 3764.75, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 1.0}
# 38: {'_id': ObjectId('6799e304a695e4e0efb5b160'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 62500000, 'LAND AREA': 2190.4, 'ROAD ACCESS': 13, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 3.0}
# 39: {'_id': ObjectId('6799e304a695e4e0efb5b161'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 160000000, 'LAND AREA': 4107.0, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 7.0, 'PROPERTY AGE': 3.0}
# 40: {'_id': ObjectId('6799e304a695e4e0efb5b162'), 'LOCATION': 'Hattiban, Lalitpur', 'PRICE': 28000000, 'LAND AREA': 752.95, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 41: {'_id': ObjectId('6799e304a695e4e0efb5b163'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 59900000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': nan, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 42: {'_id': ObjectId('6799e304a695e4e0efb5b164'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 48000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 25, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 43: {'_id': ObjectId('6799e304a695e4e0efb5b165'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 25000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 44: {'_id': ObjectId('6799e304a695e4e0efb5b166'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 40000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 18, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 5.0}
# 45: {'_id': ObjectId('6799e304a695e4e0efb5b167'), 'LOCATION': 'Nakhipot, Lalitpur', 'PRICE': 60000000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 46: {'_id': ObjectId('6799e304a695e4e0efb5b168'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 25000000, 'LAND AREA': 1197.875, 'ROAD ACCESS': 12, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 10.0}
# 47: {'_id': ObjectId('6799e304a695e4e0efb5b169'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 27000000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 12, 'FACING': 'east', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 48: {'_id': ObjectId('6799e304a695e4e0efb5b16a'), 'LOCATION': 'Gwarko, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 49: {'_id': ObjectId('6799e304a695e4e0efb5b16b'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 110000000, 'LAND AREA': 3764.75, 'ROAD ACCESS': 16, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 50: {'_id': ObjectId('6799e304a695e4e0efb5b16c'), 'LOCATION': 'Hattiban, Lalitpur', 'PRICE': 32500000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 15, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 51: {'_id': ObjectId('6799e304a695e4e0efb5b16d'), 'LOCATION': 'Hattiban, Lalitpur', 'PRICE': 28000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 52: {'_id': ObjectId('6799e304a695e4e0efb5b16e'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 31000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 12, 'FACING': 'west', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 53: {'_id': ObjectId('6799e304a695e4e0efb5b16f'), 'LOCATION': 'Baneshwor, Kathmandu', 'PRICE': 40000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 54: {'_id': ObjectId('6799e304a695e4e0efb5b170'), 'LOCATION': 'Tokha, Kathmandu', 'PRICE': 35000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 15, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 6.0}
# 55: {'_id': ObjectId('6799e304a695e4e0efb5b171'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 31500000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 56: {'_id': ObjectId('6799e304a695e4e0efb5b172'), 'LOCATION': 'Ochu Height, Lalitpur', 'PRICE': 29000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 4.0}
# 57: {'_id': ObjectId('6799e304a695e4e0efb5b173'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 42500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 58: {'_id': ObjectId('6799e304a695e4e0efb5b174'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 46500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 12, 'FACING': 'east-south', 'FLOOR': 2.0, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 59: {'_id': ObjectId('6799e304a695e4e0efb5b175'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 40000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 20, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 1.0}
# 60: {'_id': ObjectId('6799e304a695e4e0efb5b176'), 'LOCATION': 'Sanepa, Lalitpur', 'PRICE': 59500000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 16, 'FACING': 'east-north', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 61: {'_id': ObjectId('6799e304a695e4e0efb5b177'), 'LOCATION': 'Nakkhu, Lalitpur', 'PRICE': 39000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 62: {'_id': ObjectId('6799e304a695e4e0efb5b178'), 'LOCATION': 'Setipakha, Lalitpur', 'PRICE': 32000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 8.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 63: {'_id': ObjectId('6799e304a695e4e0efb5b179'), 'LOCATION': 'Setipakha, Lalitpur', 'PRICE': 32500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 8.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 64: {'_id': ObjectId('6799e304a695e4e0efb5b17a'), 'LOCATION': 'Sunakothi, Lalitpur', 'PRICE': 51500000, 'LAND AREA': 2429.975, 'ROAD ACCESS': 20, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 65: {'_id': ObjectId('6799e304a695e4e0efb5b17b'), 'LOCATION': 'Kalanki, Kathmandu', 'PRICE': 35000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 10, 'FACING': 'south', 'FLOOR': 3.5, 'BEDROOM': 8.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 6.0}
# 66: {'_id': ObjectId('6799e304a695e4e0efb5b17c'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 32500000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 67: {'_id': ObjectId('6799e304a695e4e0efb5b17d'), 'LOCATION': 'Bhangal , Kathmandu', 'PRICE': 32000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 7.0}
# 68: {'_id': ObjectId('6799e304a695e4e0efb5b17e'), 'LOCATION': 'Sukedhara, Kathmandu', 'PRICE': 55000000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 6.0}
# 69: {'_id': ObjectId('6799e304a695e4e0efb5b17f'), 'LOCATION': 'Setipakha, Lalitpur', 'PRICE': 23000000, 'LAND AREA': 787.175, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 70: {'_id': ObjectId('6799e304a695e4e0efb5b180'), 'LOCATION': 'Chandragiri, Kathmandu', 'PRICE': 17000000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.0, 'BEDROOM': 3.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 71: {'_id': ObjectId('6799e304a695e4e0efb5b181'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 24000000, 'LAND AREA': 787.175, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 72: {'_id': ObjectId('6799e304a695e4e0efb5b182'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 73: {'_id': ObjectId('6799e304a695e4e0efb5b183'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 22500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 74: {'_id': ObjectId('6799e304a695e4e0efb5b184'), 'LOCATION': 'Lubhu, Lalitpur', 'PRICE': 18000000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 75: {'_id': ObjectId('6799e304a695e4e0efb5b185'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 25000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 14, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 76: {'_id': ObjectId('6799e304a695e4e0efb5b186'), 'LOCATION': 'Setipakha, Lalitpur', 'PRICE': 16500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 1.0, 'BEDROOM': 1.0, 'BATHROOM': 1.0, 'PROPERTY AGE': 7.0}
# 77: {'_id': ObjectId('6799e304a695e4e0efb5b187'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 51000000, 'LAND AREA': 2156.1749999999997, 'ROAD ACCESS': 12, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 78: {'_id': ObjectId('6799e304a695e4e0efb5b188'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 59900000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 79: {'_id': ObjectId('6799e304a695e4e0efb5b189'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 32500000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 80: {'_id': ObjectId('6799e304a695e4e0efb5b18a'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 81: {'_id': ObjectId('6799e304a695e4e0efb5b18b'), 'LOCATION': 'Sudal, Bhaktapur', 'PRICE': 12700000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 1.0, 'BEDROOM': 2.0, 'BATHROOM': 1.0, 'PROPERTY AGE': 7.0}
# 82: {'_id': ObjectId('6799e304a695e4e0efb5b18c'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 61000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 18, 'FACING': 'south', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 11.0}
# 83: {'_id': ObjectId('6799e304a695e4e0efb5b18d'), 'LOCATION': 'Hattiban, Lalitpur', 'PRICE': 36900000, 'LAND AREA': 1403.225, 'ROAD ACCESS': 18, 'FACING': 'south', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 2.0}
# 84: {'_id': ObjectId('6799e304a695e4e0efb5b18e'), 'LOCATION': 'Sunakothi, Lalitpur', 'PRICE': 23000000, 'LAND AREA': 787.175, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.0, 'BEDROOM': 3.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 11.0}
# 85: {'_id': ObjectId('6799e304a695e4e0efb5b18f'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 32000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 14, 'FACING': 'south', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 2.0}
# 86: {'_id': ObjectId('6799e304a695e4e0efb5b190'), 'LOCATION': 'Nil Barahi Mandir, Bhaktapur', 'PRICE': 15500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 20, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 87: {'_id': ObjectId('6799e304a695e4e0efb5b191'), 'LOCATION': 'Dhapasi, Kathmandu', 'PRICE': 42500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 1.0}
# 88: {'_id': ObjectId('6799e304a695e4e0efb5b192'), 'LOCATION': 'Katyani Chowk, Kathmandu', 'PRICE': 65000000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 24, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 9.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 89: {'_id': ObjectId('6799e304a695e4e0efb5b193'), 'LOCATION': 'Gaurighat, Kathmandu', 'PRICE': 35000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 15, 'FACING': 'north', 'FLOOR': 2.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 5.0}
# 90: {'_id': ObjectId('6799e304a695e4e0efb5b194'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 28000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 5.0}
# 91: {'_id': ObjectId('6799e304a695e4e0efb5b195'), 'LOCATION': 'Lubhu, Lalitpur', 'PRICE': 13300000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 1.5, 'BEDROOM': 2.0, 'BATHROOM': 1.0, 'PROPERTY AGE': 4.0}
# 92: {'_id': ObjectId('6799e304a695e4e0efb5b196'), 'LOCATION': 'Hattigaunda, Kathmandu', 'PRICE': nan, 'LAND AREA': 5133.75, 'ROAD ACCESS': 20, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 2.0}
# 93: {'_id': ObjectId('6799e304a695e4e0efb5b197'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 16000000, 'LAND AREA': 752.95, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.0, 'BEDROOM': 4.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 6.0}
# 94: {'_id': ObjectId('6799e304a695e4e0efb5b198'), 'LOCATION': 'Harisiddhi, Lalitpur', 'PRICE': 25000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 13.0}
# 95: {'_id': ObjectId('6799e304a695e4e0efb5b199'), 'LOCATION': 'Harisiddhi, Lalitpur', 'PRICE': 28000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 96: {'_id': ObjectId('6799e304a695e4e0efb5b19a'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 27000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 14, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 97: {'_id': ObjectId('6799e304a695e4e0efb5b19b'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 39900000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 5.0}
# 98: {'_id': ObjectId('6799e304a695e4e0efb5b19c'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 49900000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 3.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 99: {'_id': ObjectId('6799e304a695e4e0efb5b19d'), 'LOCATION': 'Lubhu, Lalitpur', 'PRICE': 17000000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 10, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 100: {'_id': ObjectId('6799e304a695e4e0efb5b19e'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 42500000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 20, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 101: {'_id': ObjectId('6799e304a695e4e0efb5b19f'), 'LOCATION': 'Sanagaun, Lalitpur', 'PRICE': 17000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.0, 'BEDROOM': 4.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 4.0}
# 102: {'_id': ObjectId('6799e304a695e4e0efb5b1a0'), 'LOCATION': 'Balkot, Bhaktapur', 'PRICE': 52500000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 20, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 103: {'_id': ObjectId('6799e304a695e4e0efb5b1a1'), 'LOCATION': 'Bageshwori, Bhaktapur', 'PRICE': 25000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 104: {'_id': ObjectId('6799e304a695e4e0efb5b1a2'), 'LOCATION': 'Bhangal , Kathmandu', 'PRICE': 32000000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 2.0}
# 105: {'_id': ObjectId('6799e304a695e4e0efb5b1a3'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 25000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 18, 'FACING': 'south', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 106: {'_id': ObjectId('6799e304a695e4e0efb5b1a4'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 23500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 107: {'_id': ObjectId('6799e304a695e4e0efb5b1a5'), 'LOCATION': 'Samakhusi, Kathmandu', 'PRICE': 39000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 108: {'_id': ObjectId('6799e304a695e4e0efb5b1a6'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 33000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 5.0}
# 109: {'_id': ObjectId('6799e304a695e4e0efb5b1a7'), 'LOCATION': 'Chandol, Kathmandu', 'PRICE': 85000000, 'LAND AREA': 3182.925, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 11.0}
# 110: {'_id': ObjectId('6799e304a695e4e0efb5b1a8'), 'LOCATION': 'Hepali Height, Kathmandu', 'PRICE': 60300000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 3.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 1.0}
# 111: {'_id': ObjectId('6799e304a695e4e0efb5b1a9'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 16500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 5.0}
# 112: {'_id': ObjectId('6799e304a695e4e0efb5b1aa'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 22500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 20, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 113: {'_id': ObjectId('6799e304a695e4e0efb5b1ab'), 'LOCATION': 'Hepali Height, Kathmandu', 'PRICE': 33000000, 'LAND AREA': 2121.9500000000003, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 5.0}
# 114: {'_id': ObjectId('6799e304a695e4e0efb5b1ac'), 'LOCATION': 'Mandikhatar, Kathmandu', 'PRICE': 75000000, 'LAND AREA': 3114.475, 'ROAD ACCESS': 16, 'FACING': 'south-west', 'FLOOR': 3.5, 'BEDROOM': 8.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 5.0}
# 115: {'_id': ObjectId('6799e304a695e4e0efb5b1ad'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 116: {'_id': ObjectId('6799e304a695e4e0efb5b1ae'), 'LOCATION': 'Bojepokhari, Lalitpur', 'PRICE': 28500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 12, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 117: {'_id': ObjectId('6799e304a695e4e0efb5b1af'), 'LOCATION': 'Hattigaunda, Kathmandu', 'PRICE': 31500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 14, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 1.0}
# 118: {'_id': ObjectId('6799e304a695e4e0efb5b1b0'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 8.0}
# 119: {'_id': ObjectId('6799e304a695e4e0efb5b1b1'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 23500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 120: {'_id': ObjectId('6799e304a695e4e0efb5b1b2'), 'LOCATION': 'Thaiba, Lalitpur', 'PRICE': 29000000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 20, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 121: {'_id': ObjectId('6799e304a695e4e0efb5b1b3'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 25500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 7.0}
# 122: {'_id': ObjectId('6799e304a695e4e0efb5b1b4'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 32500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 20, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 123: {'_id': ObjectId('6799e304a695e4e0efb5b1b5'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 27000000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 124: {'_id': ObjectId('6799e304a695e4e0efb5b1b6'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 24500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 8.0}
# 125: {'_id': ObjectId('6799e304a695e4e0efb5b1b7'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 29500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 8.0}
# 126: {'_id': ObjectId('6799e304a695e4e0efb5b1b8'), 'LOCATION': 'Itahari, Sunsari', 'PRICE': nan, 'LAND AREA': 510.30182, 'ROAD ACCESS': 24, 'FACING': 'south', 'FLOOR': 4.0, 'BEDROOM': nan, 'BATHROOM': nan, 'PROPERTY AGE': 8.0}
# 127: {'_id': ObjectId('6799e304a695e4e0efb5b1b9'), 'LOCATION': 'Lasuntar, Kathmandu', 'PRICE': 25000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 12, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 1.0}
# 128: {'_id': ObjectId('6799e304a695e4e0efb5b1ba'), 'LOCATION': 'Khumaltar, Lalitpur', 'PRICE': 45000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 129: {'_id': ObjectId('6799e304a695e4e0efb5b1bb'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 24000000, 'LAND AREA': 787.175, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 8.0}
# 130: {'_id': ObjectId('6799e304a695e4e0efb5b1bc'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 23000000, 'LAND AREA': 752.95, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 8.0}
# 131: {'_id': ObjectId('6799e304a695e4e0efb5b1bd'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 26500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 7.0}
# 132: {'_id': ObjectId('6799e304a695e4e0efb5b1be'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 32000000, 'LAND AREA': 1403.225, 'ROAD ACCESS': 13, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 133: {'_id': ObjectId('6799e304a695e4e0efb5b1bf'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 29000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 5.0}
# 134: {'_id': ObjectId('6799e304a695e4e0efb5b1c0'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 135: {'_id': ObjectId('6799e304a695e4e0efb5b1c1'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 25500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 8.0}
# 136: {'_id': ObjectId('6799e304a695e4e0efb5b1c2'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 8.0}
# 137: {'_id': ObjectId('6799e304a695e4e0efb5b1c3'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 34000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 26, 'FACING': 'west', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 138: {'_id': ObjectId('6799e304a695e4e0efb5b1c4'), 'LOCATION': 'Nakkhu, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 139: {'_id': ObjectId('6799e304a695e4e0efb5b1c5'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 42500000, 'LAND AREA': 1403.225, 'ROAD ACCESS': 20, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 8.0}
# 140: {'_id': ObjectId('6799e304a695e4e0efb5b1c6'), 'LOCATION': 'Sanagaun, Lalitpur', 'PRICE': 16000000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 11.0}
# 141: {'_id': ObjectId('6799e304a695e4e0efb5b1c7'), 'LOCATION': 'Samakhushi chowk, Kathmandu', 'PRICE': 35500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 2.0}
# 142: {'_id': ObjectId('6799e304a695e4e0efb5b1c8'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 9.0}
# 143: {'_id': ObjectId('6799e304a695e4e0efb5b1c9'), 'LOCATION': 'Lubhu, Lalitpur', 'PRICE': 59000000, 'LAND AREA': 2429.975, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 7.0}
# 144: {'_id': ObjectId('6799e304a695e4e0efb5b1ca'), 'LOCATION': 'Taukhel, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 12, 'FACING': 'west', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 145: {'_id': ObjectId('6799e304a695e4e0efb5b1cb'), 'LOCATION': 'Hattiban, Lalitpur', 'PRICE': 28000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 11.0}
# 146: {'_id': ObjectId('6799e304a695e4e0efb5b1cc'), 'LOCATION': 'Hattiban, Lalitpur', 'PRICE': 32500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 14, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 18.0}
# 147: {'_id': ObjectId('6799e304a695e4e0efb5b1cd'), 'LOCATION': 'Sundarbasti, Kathmandu', 'PRICE': 39000000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 10.0}
# 148: {'_id': ObjectId('6799e304a695e4e0efb5b1ce'), 'LOCATION': 'Narayanthan , Kathmandu', 'PRICE': 42500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 15.0}
# 149: {'_id': ObjectId('6799e304a695e4e0efb5b1cf'), 'LOCATION': 'Katunje, Bhaktapur', 'PRICE': 34000000, 'LAND AREA': 1403.225, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 9.0}
# 150: {'_id': ObjectId('6799e304a695e4e0efb5b1d0'), 'LOCATION': 'Dhapasi, Kathmandu', 'PRICE': 47500000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 13.0}
# 151: {'_id': ObjectId('6799e304a695e4e0efb5b1d1'), 'LOCATION': 'Sundarbasti, Kathmandu', 'PRICE': 34500000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 9.0}
# 152: {'_id': ObjectId('6799e304a695e4e0efb5b1d2'), 'LOCATION': 'Nayapati, Kathmandu', 'PRICE': 29000000, 'LAND AREA': 2087.725, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 11.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 153: {'_id': ObjectId('6799e304a695e4e0efb5b1d3'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 26500000, 'LAND AREA': 992.525, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 154: {'_id': ObjectId('6799e304a695e4e0efb5b1d4'), 'LOCATION': 'Nakhipot, Lalitpur', 'PRICE': 42500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 16, 'FACING': 'east-south', 'FLOOR': 3.5, 'BEDROOM': 7.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 22.0}
# 155: {'_id': ObjectId('6799e304a695e4e0efb5b1d5'), 'LOCATION': 'Khumaltar, Lalitpur', 'PRICE': 42000000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 12, 'FACING': 'south', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 11.0}
# 156: {'_id': ObjectId('6799e304a695e4e0efb5b1d6'), 'LOCATION': 'Jyotinagar, Kathmandu', 'PRICE': 29500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 157: {'_id': ObjectId('6799e304a695e4e0efb5b1d7'), 'LOCATION': 'Kuleshwor, Kathmandu', 'PRICE': 45000000, 'LAND AREA': 752.95, 'ROAD ACCESS': 27, 'FACING': 'east', 'FLOOR': 5.0, 'BEDROOM': 7.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 16.0}
# 158: {'_id': ObjectId('6799e304a695e4e0efb5b1d8'), 'LOCATION': 'Khumaltar, Lalitpur', 'PRICE': 39000000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 11.0}
# 159: {'_id': ObjectId('6799e304a695e4e0efb5b1d9'), 'LOCATION': 'Dhapasi, Kathmandu', 'PRICE': 46000000, 'LAND AREA': 2464.2000000000003, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 10.0}
# 160: {'_id': ObjectId('6799e304a695e4e0efb5b1da'), 'LOCATION': 'Makalbari, Kathmandu', 'PRICE': nan, 'LAND AREA': 2738.0, 'ROAD ACCESS': 16, 'FACING': 'east', 'FLOOR': 1.0, 'BEDROOM': 2.0, 'BATHROOM': 1.0, 'PROPERTY AGE': 11.0}
# 161: {'_id': ObjectId('6799e304a695e4e0efb5b1db'), 'LOCATION': 'Bhangal , Kathmandu', 'PRICE': 24000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 11.0}
# 162: {'_id': ObjectId('6799e304a695e4e0efb5b1dc'), 'LOCATION': 'Mahadevtar, Kathmandu', 'PRICE': 60000000, 'LAND AREA': 3490.95, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 3.5, 'BEDROOM': 8.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 9.0}
# 163: {'_id': ObjectId('6799e304a695e4e0efb5b1dd'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 38500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 9.0}
# 164: {'_id': ObjectId('6799e304a695e4e0efb5b1de'), 'LOCATION': 'Pasikot, Kathmandu', 'PRICE': 28000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 165: {'_id': ObjectId('6799e304a695e4e0efb5b1df'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 23000000, 'LAND AREA': 787.175, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 3.5, 'BEDROOM': 3.0, 'BATHROOM': nan, 'PROPERTY AGE': 17.0}
# 166: {'_id': ObjectId('6799e304a695e4e0efb5b1e0'), 'LOCATION': 'Satdobato, Lalitpur', 'PRICE': 26000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 17.0}
# 167: {'_id': ObjectId('6799e304a695e4e0efb5b1e1'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 25500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 12, 'FACING': 'east', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 11.0}
# 168: {'_id': ObjectId('6799e304a695e4e0efb5b1e2'), 'LOCATION': 'Mandikhatar, Kathmandu', 'PRICE': nan, 'LAND AREA': 1129.425, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 169: {'_id': ObjectId('6799e304a695e4e0efb5b1e3'), 'LOCATION': 'Banasthali, Kathmandu', 'PRICE': 50000000, 'LAND AREA': 2738.0, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 170: {'_id': ObjectId('6799e304a695e4e0efb5b1e4'), 'LOCATION': 'Hattigaunda, Kathmandu', 'PRICE': 33000000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 11.0}
# 171: {'_id': ObjectId('6799e304a695e4e0efb5b1e5'), 'LOCATION': 'Phutung, Kathmandu', 'PRICE': 16000000, 'LAND AREA': 752.95, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 11.0}
# 172: {'_id': ObjectId('6799e304a695e4e0efb5b1e6'), 'LOCATION': 'Gurjudhara, Kathmandu', 'PRICE': 32500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 16.0}
# 173: {'_id': ObjectId('6799e304a695e4e0efb5b1e7'), 'LOCATION': 'Pasikot, Kathmandu', 'PRICE': 39000000, 'LAND AREA': 1779.7, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 22.0}
# 174: {'_id': ObjectId('6799e304a695e4e0efb5b1e8'), 'LOCATION': 'Balkumari, Lalitpur', 'PRICE': 55000000, 'LAND AREA': 3080.25, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 12.0}
# 175: {'_id': ObjectId('6799e304a695e4e0efb5b1e9'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 42500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 16, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 2.0}
# 176: {'_id': ObjectId('6799e304a695e4e0efb5b1ea'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 31000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 2.0}
# 177: {'_id': ObjectId('6799e304a695e4e0efb5b1eb'), 'LOCATION': 'Sitapaila, Kathmandu', 'PRICE': 35000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 178: {'_id': ObjectId('6799e304a695e4e0efb5b1ec'), 'LOCATION': 'Balkhu, Kathmandu', 'PRICE': 37000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 26.0}
# 179: {'_id': ObjectId('6799e304a695e4e0efb5b1ed'), 'LOCATION': 'Chandol, Kathmandu', 'PRICE': 72500000, 'LAND AREA': 2738.0, 'ROAD ACCESS': 26, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': nan, 'BATHROOM': nan, 'PROPERTY AGE': 11.0}
# 180: {'_id': ObjectId('6799e304a695e4e0efb5b1ee'), 'LOCATION': 'Tikathali, Lalitpur', 'PRICE': 28500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 11.0}
# 181: {'_id': ObjectId('6799e304a695e4e0efb5b1ef'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 36500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 7.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 9.0}
# 182: {'_id': ObjectId('6799e304a695e4e0efb5b1f0'), 'LOCATION': 'Grande Hospital, Kathmandu', 'PRICE': 33000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 2.0}
# 183: {'_id': ObjectId('6799e304a695e4e0efb5b1f1'), 'LOCATION': 'Hattigaunda, Kathmandu', 'PRICE': 62500000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 20, 'FACING': 'south', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 7.0, 'PROPERTY AGE': 26.0}
# 184: {'_id': ObjectId('6799e304a695e4e0efb5b1f2'), 'LOCATION': 'Hattigaunda, Kathmandu', 'PRICE': 75000000, 'LAND AREA': 2738.0, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 9.0}
# 185: {'_id': ObjectId('6799e304a695e4e0efb5b1f3'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 35000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 30, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 12.0}
# 186: {'_id': ObjectId('6799e304a695e4e0efb5b1f4'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 31000000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 12.0}
# 187: {'_id': ObjectId('6799e304a695e4e0efb5b1f5'), 'LOCATION': 'Gwarko, Lalitpur', 'PRICE': 23500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 2.0}
# 188: {'_id': ObjectId('6799e304a695e4e0efb5b1f6'), 'LOCATION': 'Gwarko, Lalitpur', 'PRICE': 29500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 3.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 2.0}
# 189: {'_id': ObjectId('6799e304a695e4e0efb5b1f7'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 46500000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 190: {'_id': ObjectId('6799e304a695e4e0efb5b1f8'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 31500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 8.0}
# 191: {'_id': ObjectId('6799e304a695e4e0efb5b1f9'), 'LOCATION': 'Uttardhoka, Kathmandu', 'PRICE': 15000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 20, 'FACING': 'south', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 5.0}
# 192: {'_id': ObjectId('6799e304a695e4e0efb5b1fa'), 'LOCATION': 'Budhanilkantha, Kathmandu', 'PRICE': 22500000, 'LAND AREA': 3080.25, 'ROAD ACCESS': 13, 'FACING': 'east-south', 'FLOOR': 2.0, 'BEDROOM': 2.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 9.0}
# 193: {'_id': ObjectId('6799e304a695e4e0efb5b1fb'), 'LOCATION': ' Tanahun', 'PRICE': nan, 'LAND AREA': 127.0, 'ROAD ACCESS': 266, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 9.0}
# 194: {'_id': ObjectId('6799e304a695e4e0efb5b1fc'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 19000000, 'LAND AREA': 787.175, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 2.0}
# 195: {'_id': ObjectId('6799e304a695e4e0efb5b1fd'), 'LOCATION': 'Satdobato, Lalitpur', 'PRICE': 31000000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 26.0}
# 196: {'_id': ObjectId('6799e304a695e4e0efb5b1fe'), 'LOCATION': 'Bhaisepati, Lalitpur', 'PRICE': 43500000, 'LAND AREA': 1437.45, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 9.0}
# 197: {'_id': ObjectId('6799e304a695e4e0efb5b1ff'), 'LOCATION': 'Gwarko, Lalitpur', 'PRICE': 22000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': nan, 'PROPERTY AGE': 11.0}
# 198: {'_id': ObjectId('6799e304a695e4e0efb5b200'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 31000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 9.0}
# 199: {'_id': ObjectId('6799e304a695e4e0efb5b201'), 'LOCATION': 'Sitapaila, Kathmandu', 'PRICE': 55000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 8.0}
# 200: {'_id': ObjectId('6799e304a695e4e0efb5b202'), 'LOCATION': 'Gongabu, Kathmandu', 'PRICE': 60000000, 'LAND AREA': 2429.975, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 5.0, 'BEDROOM': 10.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 5.0}
# 201: {'_id': ObjectId('6799e304a695e4e0efb5b203'), 'LOCATION': 'Imadol, Lalitpur', 'PRICE': 28000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 12.0}
# 202: {'_id': ObjectId('6799e304a695e4e0efb5b204'), 'LOCATION': 'Ochu Height, Lalitpur', 'PRICE': 27500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 203: {'_id': ObjectId('6799e304a695e4e0efb5b205'), 'LOCATION': 'Gwarko, Lalitpur', 'PRICE': 29500000, 'LAND AREA': 1095.2, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 8.0}
# 204: {'_id': ObjectId('6799e304a695e4e0efb5b206'), 'LOCATION': 'Lubhu, Lalitpur', 'PRICE': 19500000, 'LAND AREA': 787.175, 'ROAD ACCESS': 23, 'FACING': 'west', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 6.0, 'PROPERTY AGE': 5.0}
# ...
# 2718: {'_id': ObjectId('6799e304a695e4e0efb5bbd8'), 'LOCATION': 'Hatti Gauda,  Kathmandu', 'PRICE': 30000000, 'LAND AREA': 2395.75, 'ROAD ACCESS': 22, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 2719: {'_id': ObjectId('6799e304a695e4e0efb5bbd9'), 'LOCATION': ' Hatigauda,  Kathmandu', 'PRICE': 26000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 22, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 3.0}
# 2720: {'_id': ObjectId('6799e304a695e4e0efb5bbda'), 'LOCATION': ' Chandagiri,  Kathmandu', 'PRICE': 25500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2721: {'_id': ObjectId('6799e304a695e4e0efb5bbdb'), 'LOCATION': ' Syuchatar,  Kathmandu', 'PRICE': 22000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 14, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 11.0}
# 2722: {'_id': ObjectId('6799e304a695e4e0efb5bbdc'), 'LOCATION': ' Budhanilkantha,  Kathmandu', 'PRICE': 37500000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 2723: {'_id': ObjectId('6799e304a695e4e0efb5bbdd'), 'LOCATION': ' Raamkot,  Kathmandu', 'PRICE': 18500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 2724: {'_id': ObjectId('6799e304a695e4e0efb5bbde'), 'LOCATION': ' Swoyambhu,  Kathmandu', 'PRICE': 25000000, 'LAND AREA': 924.075, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 2725: {'_id': ObjectId('6799e304a695e4e0efb5bbdf'), 'LOCATION': ' Sano Bhanrayang,  Kathmandu', 'PRICE': 25000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 2726: {'_id': ObjectId('6799e304a695e4e0efb5bbe0'), 'LOCATION': ' Sitapaila,  Kathmandu', 'PRICE': 35000000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 20, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 2727: {'_id': ObjectId('6799e304a695e4e0efb5bbe1'), 'LOCATION': ' Nakhipot,  Lalitpur', 'PRICE': 28500000, 'LAND AREA': 1266.325, 'ROAD ACCESS': 18, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2728: {'_id': ObjectId('6799e304a695e4e0efb5bbe2'), 'LOCATION': ' Gairgaun,  Kathmandu', 'PRICE': 23500000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 1.0, 'BEDROOM': 8.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 6.0}
# 2729: {'_id': ObjectId('6799e304a695e4e0efb5bbe3'), 'LOCATION': ' Tokha,  Kathmandu', 'PRICE': 22500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 16, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2730: {'_id': ObjectId('6799e304a695e4e0efb5bbe4'), 'LOCATION': ' Tokha,  Kathmandu', 'PRICE': 27000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 2731: {'_id': ObjectId('6799e304a695e4e0efb5bbe5'), 'LOCATION': ' Grande,  Kathmandu', 'PRICE': 37000000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 16, 'FACING': 'south-west', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 2732: {'_id': ObjectId('6799e304a695e4e0efb5bbe6'), 'LOCATION': ' Khumaltar,  Lalitpur', 'PRICE': 35000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 3.0}
# 2733: {'_id': ObjectId('6799e304a695e4e0efb5bbe7'), 'LOCATION': ' Khumaltar,  Lalitpur', 'PRICE': 25000000, 'LAND AREA': 1197.875, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 9.0}
# 2734: {'_id': ObjectId('6799e304a695e4e0efb5bbe8'), 'LOCATION': ' Jharuwarasi,  Lalitpur', 'PRICE': 16000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 1.0, 'PROPERTY AGE': 12.0}
# 2735: {'_id': ObjectId('6799e304a695e4e0efb5bbe9'), 'LOCATION': ' Bafal,  Kathmandu', 'PRICE': 35000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 12, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 2736: {'_id': ObjectId('6799e304a695e4e0efb5bbea'), 'LOCATION': ' Ichangunarayan,  Kathmandu', 'PRICE': 27500000, 'LAND AREA': 1060.9750000000001, 'ROAD ACCESS': 12, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 3.0}
# 2737: {'_id': ObjectId('6799e304a695e4e0efb5bbeb'), 'LOCATION': ' Sitapaila,  Kathmandu', 'PRICE': 33000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 10, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 2738: {'_id': ObjectId('6799e304a695e4e0efb5bbec'), 'LOCATION': ' Kapan,  Kathmandu', 'PRICE': 47500000, 'LAND AREA': 1574.35, 'ROAD ACCESS': 15, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 6.0}
# 2739: {'_id': ObjectId('6799e304a695e4e0efb5bbed'), 'LOCATION': ' Tarkeshwor,  Kathmandu', 'PRICE': 23000000, 'LAND AREA': 1711.25, 'ROAD ACCESS': 18, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 10.0}
# 2740: {'_id': ObjectId('6799e304a695e4e0efb5bbee'), 'LOCATION': ' Sano Bharayang,  Kathmandu', 'PRICE': 50000000, 'LAND AREA': 3422.5, 'ROAD ACCESS': 14, 'FACING': 'west', 'FLOOR': 3.5, 'BEDROOM': 8.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 10.0}
# 2741: {'_id': ObjectId('6799e304a695e4e0efb5bbef'), 'LOCATION': 'Banasthali,  Kathmandu', 'PRICE': 70000000, 'LAND AREA': 3764.75, 'ROAD ACCESS': 20, 'FACING': 'east', 'FLOOR': 2.0, 'BEDROOM': 4.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 10.0}
# 2742: {'_id': ObjectId('6799e304a695e4e0efb5bbf0'), 'LOCATION': ' Nepaltar,  Kathmandu', 'PRICE': 36500000, 'LAND AREA': 1813.925, 'ROAD ACCESS': 13, 'FACING': 'west', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 6.0}
# 2743: {'_id': ObjectId('6799e304a695e4e0efb5bbf1'), 'LOCATION': ' Dahachowk,  Kathmandu', 'PRICE': 18500000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 3.0, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2744: {'_id': ObjectId('6799e304a695e4e0efb5bbf2'), 'LOCATION': ' Budhanilkantha,  Kathmandu', 'PRICE': 55000000, 'LAND AREA': 2566.875, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2745: {'_id': ObjectId('6799e304a695e4e0efb5bbf3'), 'LOCATION': ' Sano Bhanrayang,  Kathmandu', 'PRICE': 31500000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 3.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 4.0}
# 2746: {'_id': ObjectId('6799e304a695e4e0efb5bbf4'), 'LOCATION': ' Budhanilkantha,  Kathmandu', 'PRICE': 70000000, 'LAND AREA': 5476.0, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 5.0, 'BEDROOM': 4.0, 'BATHROOM': 7.0, 'PROPERTY AGE': 5.0}
# 2747: {'_id': ObjectId('6799e304a695e4e0efb5bbf5'), 'LOCATION': ' Sano Bhanrayang,  Kathmandu', 'PRICE': 27000000, 'LAND AREA': 1129.425, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2748: {'_id': ObjectId('6799e304a695e4e0efb5bbf6'), 'LOCATION': ' Sitapaila,  Kathmandu', 'PRICE': 28000000, 'LAND AREA': 1197.875, 'ROAD ACCESS': 12, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 3.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2749: {'_id': ObjectId('6799e304a695e4e0efb5bbf7'), 'LOCATION': ' Sitapaila,  Kathmandu', 'PRICE': 23000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2750: {'_id': ObjectId('6799e304a695e4e0efb5bbf8'), 'LOCATION': ' Kusunti,  Lalitpur', 'PRICE': 36500000, 'LAND AREA': 1848.15, 'ROAD ACCESS': 16, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2751: {'_id': ObjectId('6799e304a695e4e0efb5bbf9'), 'LOCATION': ' Mahankal ,  Kathmandu', 'PRICE': 23000000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 16, 'FACING': 'east', 'FLOOR': 1.0, 'BEDROOM': 6.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2752: {'_id': ObjectId('6799e304a695e4e0efb5bbfa'), 'LOCATION': ' Sitapaila,  Kathmandu', 'PRICE': 24000000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 16, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 2753: {'_id': ObjectId('6799e304a695e4e0efb5bbfb'), 'LOCATION': 'dallu,  kathmandu', 'PRICE': 40000000, 'LAND AREA': 1608.575, 'ROAD ACCESS': 16, 'FACING': 'west', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 20.0}
# 2754: {'_id': ObjectId('6799e304a695e4e0efb5bbfc'), 'LOCATION': ' Budhanilkantha,  Kathmandu', 'PRICE': 105000000, 'LAND AREA': 7187.25, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 20.0}
# 2755: {'_id': ObjectId('6799e304a695e4e0efb5bbfd'), 'LOCATION': ' Budhanikantha,  Kathmandu', 'PRICE': 45000000, 'LAND AREA': 2053.5, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 6.0}
# 2756: {'_id': ObjectId('6799e304a695e4e0efb5bbfe'), 'LOCATION': ' Budhanilkantha,  Narayanthan', 'PRICE': 120000000, 'LAND AREA': 3422.5, 'ROAD ACCESS': 16, 'FACING': 'east-south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 12.0}
# 2757: {'_id': ObjectId('6799e304a695e4e0efb5bbff'), 'LOCATION': ' Budhanilkantha,  Kathmandu', 'PRICE': 100000000, 'LAND AREA': 2738.0, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 3.5, 'BEDROOM': 5.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 7.0}
# 2758: {'_id': ObjectId('6799e304a695e4e0efb5bc00'), 'LOCATION': ' Sano Bhanrayang,  Kathmandu', 'PRICE': 30000000, 'LAND AREA': 1197.875, 'ROAD ACCESS': 12, 'FACING': 'south', 'FLOOR': 2.0, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 7.0}
# 2759: {'_id': ObjectId('6799e304a695e4e0efb5bc01'), 'LOCATION': ' Budhanilkantha,  Kathmandu', 'PRICE': 55000000, 'LAND AREA': 2566.875, 'ROAD ACCESS': 16, 'FACING': 'south-west', 'FLOOR': 3.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2760: {'_id': ObjectId('6799e304a695e4e0efb5bc02'), 'LOCATION': ' Gongabu,  Kathmandu', 'PRICE': 90000000, 'LAND AREA': 4107.0, 'ROAD ACCESS': 16, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 14.0, 'BATHROOM': 10.0, 'PROPERTY AGE': 4.0}
# 2761: {'_id': ObjectId('6799e304a695e4e0efb5bc03'), 'LOCATION': ' Boudha,  Kathmandu', 'PRICE': 185000000, 'LAND AREA': 3764.75, 'ROAD ACCESS': 12, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 11.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 16.0}
# 2762: {'_id': ObjectId('6799e304a695e4e0efb5bc04'), 'LOCATION': ' Halchowk,  Kathmandu', 'PRICE': 36000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 13, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 16.0}
# 2763: {'_id': ObjectId('6799e304a695e4e0efb5bc05'), 'LOCATION': ' Sitapaila,  Kathmandu', 'PRICE': 31500000, 'LAND AREA': 1813.925, 'ROAD ACCESS': 13, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 5.0, 'PROPERTY AGE': 6.0}
# 2764: {'_id': ObjectId('6799e304a695e4e0efb5bc06'), 'LOCATION': ' Dhapasi,  Kathmandu', 'PRICE': 25000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 6.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 7.0}
# 2765: {'_id': ObjectId('6799e304a695e4e0efb5bc07'), 'LOCATION': ' Sano Bhanrayang,  Kathmandu', 'PRICE': 34000000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 13, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 6.0}
# 2766: {'_id': ObjectId('6799e304a695e4e0efb5bc08'), 'LOCATION': ' Chauni,  Kathmandu', 'PRICE': 27000000, 'LAND AREA': 1574.35, 'ROAD ACCESS': 20, 'FACING': 'east-south', 'FLOOR': 3.0, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 16.0}
# 2767: {'_id': ObjectId('6799e304a695e4e0efb5bc09'), 'LOCATION': ' Raniban,  Kathmandu', 'PRICE': 30000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 20, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2768: {'_id': ObjectId('6799e304a695e4e0efb5bc0a'), 'LOCATION': ' Satungal,  Kathmandu', 'PRICE': 18000000, 'LAND AREA': 1232.1000000000001, 'ROAD ACCESS': 16, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2769: {'_id': ObjectId('6799e304a695e4e0efb5bc0b'), 'LOCATION': ' Satungal,  Kathmandu', 'PRICE': 18000000, 'LAND AREA': 1232.1000000000001, 'ROAD ACCESS': 12, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2770: {'_id': ObjectId('6799e304a695e4e0efb5bc0c'), 'LOCATION': ' Thankot,  Kathmandu', 'PRICE': 16500000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 12, 'FACING': 'west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2771: {'_id': ObjectId('6799e304a695e4e0efb5bc0d'), 'LOCATION': ' Thankot,  Kathmandu', 'PRICE': 14000000, 'LAND AREA': 1026.75, 'ROAD ACCESS': 16, 'FACING': 'east', 'FLOOR': 2.5, 'BEDROOM': 2.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2772: {'_id': ObjectId('6799e304a695e4e0efb5bc0e'), 'LOCATION': ' Halchowk,  Kathmandu', 'PRICE': 26000000, 'LAND AREA': 1471.675, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2773: {'_id': ObjectId('6799e304a695e4e0efb5bc0f'), 'LOCATION': ' Swoyambhu,  Kathmandu', 'PRICE': 34000000, 'LAND AREA': 1369.0, 'ROAD ACCESS': 13, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 6.0}
# 2774: {'_id': ObjectId('6799e304a695e4e0efb5bc10'), 'LOCATION': 'Tahachal,  Kathmandu', 'PRICE': 55000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 16, 'FACING': 'east-north', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 9.0, 'PROPERTY AGE': 4.0}
# 2775: {'_id': ObjectId('6799e304a695e4e0efb5bc11'), 'LOCATION': 'Tahachal,  Kathmandu', 'PRICE': 52500000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 7.0, 'BATHROOM': 8.0, 'PROPERTY AGE': 4.0}
# 2776: {'_id': ObjectId('6799e304a695e4e0efb5bc12'), 'LOCATION': 'Kalanki,  Kathmandu', 'PRICE': 30000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 16, 'FACING': 'south-west', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2777: {'_id': ObjectId('6799e304a695e4e0efb5bc13'), 'LOCATION': ' Raniban,  Kathmandu', 'PRICE': 30000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2778: {'_id': ObjectId('6799e304a695e4e0efb5bc14'), 'LOCATION': ' Tarkeshwor,  Kathmandhu', 'PRICE': 21000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 4.0}
# 2779: {'_id': ObjectId('6799e304a695e4e0efb5bc15'), 'LOCATION': ' Sitapiala,  Kathmandu', 'PRICE': 26000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 5.0}
# 2780: {'_id': ObjectId('6799e304a695e4e0efb5bc16'), 'LOCATION': ' Bhatbhateni,  Kathmandu', 'PRICE': 30000000, 'LAND AREA': 1540.125, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 3.0, 'BEDROOM': 3.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 5.0}
# 2781: {'_id': ObjectId('6799e304a695e4e0efb5bc17'), 'LOCATION': ' Syuchatar,  Kathmandu', 'PRICE': 16000000, 'LAND AREA': 1608.575, 'ROAD ACCESS': 16, 'FACING': 'south', 'FLOOR': 2.5, 'BEDROOM': 4.0, 'BATHROOM': 2.0, 'PROPERTY AGE': 9.0}
# 2782: {'_id': ObjectId('6799e304a695e4e0efb5bc18'), 'LOCATION': ' Sano Bharayang,  Kathmandu', 'PRICE': 35000000, 'LAND AREA': 2156.1749999999997, 'ROAD ACCESS': 16, 'FACING': 'north-west', 'FLOOR': 2.5, 'BEDROOM': 5.0, 'BATHROOM': 3.0, 'PROPERTY AGE': 4.0}
# 2783: {'_id': ObjectId('6799e304a695e4e0efb5bc19'), 'LOCATION': ' Budhanilkantha,  Kathmandu', 'PRICE': 48000000, 'LAND AREA': 2738.0, 'ROAD ACCESS': 16, 'FACING': 'north', 'FLOOR': 2.0, 'BEDROOM': 5.0, 'BATHROOM': 4.0, 'PROPERTY AGE': 6.0}

# %% [markdown]
# ### CREATING THE DATAFRAME

# %%
dataset = pd.DataFrame(list(collection.find()))
dataset.head()
# Out:
#                         _id              LOCATION     PRICE LAND AREA  \
# 0  6799e304a695e4e0efb5b13a      Imadol, Lalitpur  29000000    1369.0
# 1  6799e304a695e4e0efb5b13b   Satdobato, Lalitpur  47500000   1026.75
# 2  6799e304a695e4e0efb5b13c      Imadol, Lalitpur  19900000   787.175
# 3  6799e304a695e4e0efb5b13d  Bhaisepati, Lalitpur  40000000   2395.75
# 4  6799e304a695e4e0efb5b13e  Bhaisepati, Lalitpur  33000000    1095.2
#
#   ROAD ACCESS      FACING  FLOOR  BEDROOM  BATHROOM  PROPERTY AGE
# 0          12        west    3.0      5.0       4.0           5.0
# 1          10        west    4.5      5.0       6.0           5.0
# 2          10        west    2.5      4.0       4.0          21.0
# 3          12  north-west    2.5      4.0       3.0          22.0
# 4          13  north-west    2.5      4.0       3.0           7.0

# %%
if "_id" in dataset.columns.to_list():
    dataset = dataset.drop(columns=["_id"], axis=1)

# %% [markdown]
# ### Saving the dataset into csv

# %%
dataset.to_csv("nepalhousing_dataset.csv",index=False)
