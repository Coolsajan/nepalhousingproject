# %%
print('hi')
# Out:
# hi

# %%
import pandas as pd
df=pd.read_csv('nepal_hosuing_datetset.csv')
df.head()
# Out:
#         price               location     area facing  no_of_bedroom  \
# 0  32000000.0  Shital height, Imadol  1069.53   east            5.0
# 1  28000000.0          Shital Height  1026.75   west            5.0
# 2  40000000.0  Shital height, Imadol  1369.00  north            6.0
# 3  28000000.0             Bhaisepati  1369.00  south            6.0
# 4  40000000.0             Harisiddhi  2395.75   east            6.0
#
#    no_of_bathroom  no_of_livingroom  no_of_kitchen  parking  road_size  \
# 0             4.0               2.0            3.0      4.0       13.0
# 1             4.0               2.0            3.5      2.0       13.0
# 2             4.0               2.0            2.5      4.0       13.0
# 3             3.0               2.0            2.5      4.0       16.0
# 4             4.0               2.0            2.5      4.0       13.0
#
#          furniture  no_of_flat
# 0   semi-furnished         3.0
# 1   semi-furnished         3.5
# 2  fully-furnished         2.5
# ...

# %%
dict_data=df.to_dict(orient='records')

# %%
import pymongo

# %%
DB_NAME='nepal_housing_project'
COLLECTION_NAME='housing_data'
CONNECTION_URL='mongodb+srv://housing_project:nepalproject@cluster0.va2na.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
client=pymongo.MongoClient(CONNECTION_URL)
data_base=client[DB_NAME]
collection=data_base[COLLECTION_NAME]
rec = collection.insert_many(dict_data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('67888831e1d5c3ed51254e77'), 'price': 32000000.0, 'location': 'Shital height, Imadol', 'area': 1069.53, 'facing': 'east', 'no_of_bedroom': 5.0, 'no_of_bathroom': 4.0, 'no_of_livingroom': 2.0, 'no_of_kitchen': 3.0, 'parking': 4.0, 'road_size': 13.0, 'furniture': 'semi-furnished', 'no_of_flat': 3.0}
# 1: {'_id': ObjectId('67888831e1d5c3ed51254e78'), 'price': 28000000.0, 'location': 'Shital Height', 'area': 1026.75, 'facing': 'west', 'no_of_bedroom': 5.0, 'no_of_bathroom': 4.0, 'no_of_livingroom': 2.0, 'no_of_kitchen': 3.5, 'parking': 2.0, 'road_size': 13.0, 'furniture': 'semi-furnished', 'no_of_flat': 3.5}
# 2: {'_id': ObjectId('67888831e1d5c3ed51254e79'), 'price': 40000000.0, 'location': 'Shital height, Imadol', 'area': 1369.0, 'facing': 'north', 'no_of_bedroom': 6.0, 'no_of_bathroom': 4.0, 'no_of_livingroom': 2.0, 'no_of_kitchen': 2.5, 'parking': 4.0, 'road_size': 13.0, 'furniture': 'fully-furnished', 'no_of_flat': 2.5}
# ...
